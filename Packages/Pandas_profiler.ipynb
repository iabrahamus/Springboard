# %%
import numpy as np
import pandas as pd
# Load profiler package
from pandas_profiling import ProfileReport
import pandas_profiling

df = pd.DataFrame(
    np.random.rand(100, 5),
    columns=["a", "b", "c", "d", "e"]
)



# To generate profiler report for dataframe df: Run command below


profile = ProfileReport(df, title = 'Pandas Profiling Report')

# %%
# Out:
# Collecting pandas-profiling==2.9.0
#   Using cached pandas_profiling-2.9.0-py2.py3-none-any.whl (258 kB)
# Requirement already satisfied, skipping upgrade: attrs>=19.3.0 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (19.3.0)
# Requirement already satisfied, skipping upgrade: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (1.2.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.0 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (1.18.1)
# Requirement already satisfied, skipping upgrade: ipywidgets>=7.5.1 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (7.5.1)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Processing c:\users\iabra\appdata\local\pip\cache\wheels\f1\41\d0\1f1acd2606744b6eea651fc3cfcaf3447b2961814eaefb15e9\phik-0.11.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: visions[type_image_path]==0.5.0 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (0.5.0)
# Processing c:\users\iabra\appdata\local\pip\cache\wheels\70\e1\52\5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655\htmlmin-0.1.12-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: tangled-up-in-unicode>=0.0.6 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (0.0.6)
# Collecting requests>=2.23.0
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting seaborn>=0.10.1
#   Using cached seaborn-0.11.1-py3-none-any.whl (285 kB)
# Collecting confuse>=1.0.0
#   Using cached confuse-1.4.0-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied, skipping upgrade: jinja2>=2.11.1 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (2.11.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.2.0 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (3.3.4)
# Requirement already satisfied, skipping upgrade: tqdm>=4.43.0 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (4.56.2)
# Requirement already satisfied, skipping upgrade: scipy>=1.4.1 in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib in c:\users\iabra\anaconda3\lib\site-packages (from pandas-profiling==2.9.0) (0.14.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in c:\users\iabra\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==2.9.0) (2019.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\iabra\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==2.9.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\iabra\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.9.0) (5.1.4)
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in c:\users\iabra\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.9.0) (7.12.0)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\iabra\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.9.0) (5.0.4)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\iabra\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.9.0) (4.3.3)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in c:\users\iabra\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.9.0) (3.5.1)
# Requirement already satisfied, skipping upgrade: numba>=0.38.1 in c:\users\iabra\anaconda3\lib\site-packages (from phik>=0.9.10->pandas-profiling==2.9.0) (0.48.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.4 in c:\users\iabra\anaconda3\lib\site-packages (from visions[type_image_path]==0.5.0->pandas-profiling==2.9.0) (2.4)
# Requirement already satisfied, skipping upgrade: Pillow; extra == "type_image_path" in c:\users\iabra\anaconda3\lib\site-packages (from visions[type_image_path]==0.5.0->pandas-profiling==2.9.0) (7.0.0)
# Requirement already satisfied, skipping upgrade: imagehash; extra == "type_image_path" in c:\users\iabra\anaconda3\lib\site-packages (from visions[type_image_path]==0.5.0->pandas-profiling==2.9.0) (4.2.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in c:\users\iabra\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling==2.9.0) (1.25.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\iabra\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling==2.9.0) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<5,>=3.0.2 in c:\users\iabra\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling==2.9.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\iabra\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling==2.9.0) (2019.11.28)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\iabra\anaconda3\lib\site-packages (from confuse>=1.0.0->pandas-profiling==2.9.0) (5.3)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\iabra\anaconda3\lib\site-packages (from jinja2>=2.11.1->pandas-profiling==2.9.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\users\iabra\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==2.9.0) (2.4.6)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\iabra\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==2.9.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\iabra\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==2.9.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\iabra\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==2.9.0) (1.14.0)
# Requirement already satisfied, skipping upgrade: jupyter-client in c:\users\iabra\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (5.3.4)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in c:\users\iabra\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (6.0.3)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\iabra\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.14.1)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\iabra\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.4.3)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\iabra\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (4.4.1)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\iabra\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (3.0.3)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\iabra\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (2.5.2)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in c:\users\iabra\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (45.2.0.post20200210)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\iabra\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.7.5)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\iabra\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.1.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\iabra\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.2.0)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\iabra\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (3.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\iabra\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (4.6.1)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\iabra\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (6.0.3)
# Requirement already satisfied, skipping upgrade: llvmlite<0.32.0,>=0.31.0dev0 in c:\users\iabra\anaconda3\lib\site-packages (from numba>=0.38.1->phik>=0.9.10->pandas-profiling==2.9.0) (0.31.0)
# Requirement already satisfied, skipping upgrade: PyWavelets in c:\users\iabra\anaconda3\lib\site-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.5.0->pandas-profiling==2.9.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in c:\users\iabra\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (227)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in c:\users\iabra\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (18.1.1)
# Requirement already satisfied, skipping upgrade: parso>=0.5.0 in c:\users\iabra\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.5.2)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\iabra\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.1.8)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\iabra\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.15.7)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in c:\users\iabra\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (1.5.0)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\iabra\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (5.6.1)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in c:\users\iabra\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.8.3)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\iabra\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.7.1)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\iabra\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (1.5.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in c:\users\iabra\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (2.2.0)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\iabra\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (3.1.0)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in c:\users\iabra\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.8.4)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\iabra\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.4.4)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\iabra\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.6.0)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\iabra\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (1.4.2)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\iabra\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.3)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\iabra\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.9.0) (0.5.1)
# Installing collected packages: seaborn, missingno, phik, htmlmin, requests, confuse, pandas-profiling
# Successfully installed confuse-1.4.0 htmlmin-0.1.12 missingno-0.4.2 pandas-profiling-2.9.0 phik-0.11.0 requests-2.25.1 seaborn-0.11.1
#   WARNING: The script phik_trial.exe is installed in 'C:\Users\iabra\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script htmlmin.exe is installed in 'C:\Users\iabra\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pandas_profiling.exe is installed in 'C:\Users\iabra\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
